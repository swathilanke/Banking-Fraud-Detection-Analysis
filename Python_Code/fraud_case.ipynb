# %%
import pandas as pd
import numpy as np

# !pip install fuzzywuzzy python-Levenshtein
from fuzzywuzzy import process
# Out:
# Requirement already satisfied: fuzzywuzzy in c:\users\swath\downloads\python\lib\site-packages (0.18.0)
# Requirement already satisfied: python-Levenshtein in c:\users\swath\downloads\python\lib\site-packages (0.27.1)
# Requirement already satisfied: Levenshtein==0.27.1 in c:\users\swath\downloads\python\lib\site-packages (from python-Levenshtein) (0.27.1)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.9.0 in c:\users\swath\downloads\python\lib\site-packages (from Levenshtein==0.27.1->python-Levenshtein) (3.14.1)

# %%
df = pd.read_csv('fact_fraud_case.csv')

# %%
df.shape
# Out:
# (2515, 7)

# %%
df.head()
# Out:
#    fraud_id  transaction_id        fraud_type    detection_method report_date  \
# 0         1               4           Vishing            AI Alert  17/02/2024
# 1         2            8197          Smishing  Customer Complaint  25/06/2019
# 2         3            8199  Chargeback Fraud            AI Alert  2020-09-14
# 3         4               7  Account Takeover            AI Alert  2024-06-29
# 4         5               9           Vishing  Customer Complaint  2020/12/31
#
#   resolution_status loss_amount
# 0            Closed     2911.34
# 1     Investigating     5331.17
# 2        Resolved      28211.42
# 3          Resolved    10280.88
# 4            Closed     5322.88

# %%
df.isnull().sum()
# Out:
# fraud_id             0
# transaction_id       0
# fraud_type           0
# detection_method     0
# report_date          0
# resolution_status    0
# loss_amount          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(15)

# %%
df.drop_duplicates()
# Out:
#       fraud_id  transaction_id        fraud_type    detection_method  \
# 0            1               4           Vishing            AI Alert
# 1            2            8197          Smishing  Customer Complaint
# 2            3            8199  Chargeback Fraud            AI Alert
# 3            4               7  Account Takeover            AI Alert
# 4            5               9           Vishing  Customer Complaint
# ...        ...             ...               ...                 ...
# 2495      2496            8156  Account aTkeover            AI Alert
# 2496      2497            8162    Identity Theft  Customer Complaint
# 2497      2498            8179           Vishing            AI Alert
# 2498      2499            8183          Phishing       Manual Review
# 2499      2500            8188           Vishing  Customer Complaint
#
#      report_date resolution_status loss_amount
# 0     17/02/2024            Closed     2911.34
# 1     25/06/2019     Investigating     5331.17
# 2     2020-09-14        Resolved      28211.42
# 3     2024-06-29          Resolved    10280.88
# 4     2020/12/31            Closed     5322.88
# ...          ...               ...         ...
# 2495  2021-06-15     Investigating     3505.91
# 2496  11-09-2024            Closed   -10902.92
# 2497  13/07/2025     Investigating    21524.74
# 2498  30/06/2020            Closed     5839.43
# 2499  2024-11-02          Resolved    37011.08
#
# [2500 rows x 7 columns]

# %%
# 1. Fix issue_date - convert to datetime
df['report_date'] = pd.to_datetime(df['report_date'], format='mixed', dayfirst=True)

# %%
df['report_date'] = pd.to_datetime(df['report_date'], errors='coerce')
df.dtypes
# Out:
# fraud_id                      int64
# transaction_id                int64
# fraud_type                   object
# detection_method             object
# report_date          datetime64[ns]
# resolution_status            object
# loss_amount                  object
# dtype: object

# %%
df.isnull().sum()
# Out:
# fraud_id             0
# transaction_id       0
# fraud_type           0
# detection_method     0
# report_date          0
# resolution_status    0
# loss_amount          0
# dtype: int64

# %%
# Step 1: Basic clean
df['fraud_type'] = (df['fraud_type'].astype(str).str.strip().str.lower())

# %%
# Step 2: List of correct fraud types
valid_fraud_types = [
    'phishing',
    'vishing',
    'identity theft',
    'chargeback fraud',
    'card cloning',
    'account takeover',
    'smishing'
]

# %%
# Step 3: Fuzzy match function
def clean_fraud_type(x):
    match, score = process.extractOne(x, valid_fraud_types)
    return match if score >= 60 else x

# %%
# Step 4: Apply auto-correction
df['fraud_type'] = df['fraud_type'].apply(clean_fraud_type)

# %%
# Step 5: Proper formatting (Title Case)
df['fraud_type'] = df['fraud_type'].replace({
    'phishing': 'Phishing',
    'vishing': 'Vishing',
    'identity theft': 'Identity Theft',
    'chargeback fraud': 'Chargeback Fraud',
    'card cloning': 'Card Cloning',
    'account takeover': 'Account Takeover',
    'smishing': 'Smishing'
})

# %%
print(df['fraud_type'].value_counts())
print(df['fraud_type'].unique())
# Out:
# fraud_type
# Phishing            385
# Chargeback Fraud    381
# Account Takeover    362
# Identity Theft      351
# Vishing             347
# Smishing            345
# Card Cloning        344
# Name: count, dtype: int64
# ['Vishing' 'Smishing' 'Chargeback Fraud' 'Account Takeover' 'Card Cloning'
#  'Phishing' 'Identity Theft']

# %%
# 1. Basic clean
df['detection_method'] = (df['detection_method'].astype(str).str.strip().str.lower())

# %%
# 2. Valid final categories
valid_detection = [
    'ai alert',
    'customer complaint',
    'manual review'
]

# %%
# 3. Fuzzy correction
def clean_detection(x):
    match, score = process.extractOne(x, valid_detection)
    return match if score >= 60 else x

# %%
df['detection_method'] = df['detection_method'].apply(clean_detection)

# %%
# 4. Nice casing
df['detection_method'] = df['detection_method'].replace({
    'ai alert': 'AI Alert',
    'customer complaint': 'Customer Complaint',
    'manual review': 'Manual Review'
})

# %%
# 5. Check
print(df['detection_method'].value_counts())
print(df['detection_method'].unique())
# Out:
# detection_method
# Customer Complaint    851
# AI Alert              840
# Manual Review         824
# Name: count, dtype: int64
# ['AI Alert' 'Customer Complaint' 'Manual Review']

# %%
# 1. Basic clean: strip + lowercase
df['resolution_status'] = (df['resolution_status'].astype(str).str.strip().str.lower())

# %%
# Map to correct final names
df['resolution_status'] = df['resolution_status'].replace({
    'investigating': 'Investigating',
    'closed': 'Closed',
    'resolved': 'Resolved'
})

# %%
df.isnull().sum()
# Out:
# fraud_id             0
# transaction_id       0
# fraud_type           0
# detection_method     0
# report_date          0
# resolution_status    0
# loss_amount          0
# dtype: int64

# %%
df['resolution_status'].value_counts()
df['resolution_status'].unique()
# Out:
# array(['Closed', 'Investigating', 'Resolved'], dtype=object)

# %%
df.head(130)
# Out:
#      fraud_id  transaction_id        fraud_type    detection_method  \
# 0           1               4           Vishing            AI Alert
# 1           2            8197          Smishing  Customer Complaint
# 2           3            8199  Chargeback Fraud            AI Alert
# 3           4               7  Account Takeover            AI Alert
# 4           5               9           Vishing  Customer Complaint
# ..        ...             ...               ...                 ...
# 125       126            8472          Smishing  Customer Complaint
# 126       127             283           Vishing       Manual Review
# 127       128             286          Phishing  Customer Complaint
# 128       129             287  Chargeback Fraud       Manual Review
# 129       130             289           Vishing  Customer Complaint
#
#     report_date resolution_status loss_amount
# 0    2024-02-17            Closed     2911.34
# 1    2019-06-25     Investigating     5331.17
# 2    2020-09-14          Resolved    28211.42
# 3    2024-06-29          Resolved    10280.88
# 4    2020-12-31            Closed     5322.88
# ..          ...               ...         ...
# 125  2023-10-06            Closed    12600.42
# 126  2023-06-06          Resolved     9367.22
# 127  2024-06-20          Resolved    12005.76
# 128  2020-12-14     Investigating    24112.56
# 129  2021-08-13            Closed    11309.89
#
# [130 rows x 7 columns]

# %%
# 5. Fix amount - remove currency symbols and commas
df['loss_amount'] = df['loss_amount'].astype(str).str.replace('₹', '').str.replace(',', '')
df['loss_amount'] = df['loss_amount'].astype(float)
df.dtypes
# Out:
# fraud_id                      int64
# transaction_id                int64
# fraud_type                   object
# detection_method             object
# report_date          datetime64[ns]
# resolution_status            object
# loss_amount                 float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# fraud_id             0
# transaction_id       0
# fraud_type           0
# detection_method     0
# report_date          0
# resolution_status    0
# loss_amount          0
# dtype: int64

# %%
df.shape
# Out:
# (2515, 7)

# %%
df.duplicated().sum()
# Out:
# np.int64(15)

# %%
df.duplicated('fraud_id').sum()
# Out:
# np.int64(15)

# %%
df[df.duplicated('fraud_id', keep=False)].sort_values('fraud_id')
# Out:
#       fraud_id  transaction_id        fraud_type    detection_method  \
# 85          86             170          Phishing  Customer Complaint
# 2505        86             170          Phishing  Customer Complaint
# 2503       137            8498    Identity Theft            AI Alert
# 136        137            8498    Identity Theft            AI Alert
# 195        196             476  Account Takeover  Customer Complaint
# 2511       196             476  Account Takeover  Customer Complaint
# 2500       259             627          Smishing       Manual Review
# 258        259             627          Smishing       Manual Review
# 2504       462            1147  Chargeback Fraud  Customer Complaint
# 461        462            1147  Chargeback Fraud  Customer Complaint
# 766        767            9995  Chargeback Fraud       Manual Review
# 2513       767            9995  Chargeback Fraud       Manual Review
# 2502       934            2242           Vishing            AI Alert
# 933        934            2242           Vishing            AI Alert
# 1185      1186            2841          Smishing       Manual Review
# 2512      1186            2841          Smishing       Manual Review
# 1683      1684            4206           Vishing       Manual Review
# 2501      1684            4206           Vishing       Manual Review
# 2510      1843            4962          Smishing  Customer Complaint
# 1842      1843            4962          Smishing  Customer Complaint
# 1948      1949            5508          Smishing  Customer Complaint
# 2509      1949            5508          Smishing  Customer Complaint
# 2506      2225            6867      Card Cloning  Customer Complaint
# 2224      2225            6867      Card Cloning  Customer Complaint
# 2342      2343            7373  Chargeback Fraud            AI Alert
# 2507      2343            7373  Chargeback Fraud            AI Alert
# 2514      2365            7497  Account Takeover            AI Alert
# 2364      2365            7497  Account Takeover            AI Alert
# 2497      2498            8179           Vishing            AI Alert
# 2508      2498            8179           Vishing            AI Alert
#
#      report_date resolution_status  loss_amount
# 85    2023-04-19     Investigating      4598.48
# 2505  2023-04-19     Investigating      4598.48
# 2503  2021-03-02            Closed     24897.02
# 136   2021-03-02            Closed     24897.02
# 195   2020-06-22          Resolved     21650.18
# 2511  2020-06-22          Resolved     21650.18
# 2500  2021-03-08            Closed     15343.29
# 258   2021-03-08            Closed     15343.29
# 2504  2022-07-07     Investigating     32938.68
# 461   2022-07-07     Investigating     32938.68
# 766   2025-03-31          Resolved     14367.64
# 2513  2025-03-31          Resolved     14367.64
# 2502  2019-11-06          Resolved     21132.39
# 933   2019-11-06          Resolved     21132.39
# 1185  2021-07-14     Investigating       889.07
# 2512  2021-07-14     Investigating       889.07
# 1683  2022-10-30            Closed      2894.04
# 2501  2022-10-30            Closed      2894.04
# 2510  2019-11-24            Closed      3999.93
# 1842  2019-11-24            Closed      3999.93
# 1948  2022-09-16            Closed     15444.14
# 2509  2022-09-16            Closed     15444.14
# 2506  2019-07-30          Resolved      9958.48
# 2224  2019-07-30          Resolved      9958.48
# 2342  2021-11-23          Resolved     25002.81
# 2507  2021-11-23          Resolved     25002.81
# 2514  2021-12-13     Investigating     16078.90
# 2364  2021-12-13     Investigating     16078.90
# 2497  2025-07-13     Investigating     21524.74
# 2508  2025-07-13     Investigating     21524.74

# %%
df = df.drop_duplicates(subset='fraud_id', keep='first')

# %%
df[df.duplicated('fraud_id', keep=False)]
# Out:
# Empty DataFrame
# Columns: [fraud_id, transaction_id, fraud_type, detection_method, report_date, resolution_status, loss_amount]
# Index: []

# %%
df.duplicated().sum()
df.shape
# Out:
# (2500, 7)

# %%
#fraud_case.csv → fix negative loss_amount
df['loss_amount'] = df['loss_amount'].abs()

# %%
df[df['loss_amount'] < 0]
# Out:
# Empty DataFrame
# Columns: [fraud_id, transaction_id, fraud_type, detection_method, report_date, resolution_status, loss_amount]
# Index: []

# %%
df.head(25)
# Out:
#     fraud_id  transaction_id        fraud_type    detection_method  \
# 0          1               4           Vishing            AI Alert
# 1          2            8197          Smishing  Customer Complaint
# 2          3            8199  Chargeback Fraud            AI Alert
# 3          4               7  Account Takeover            AI Alert
# 4          5               9           Vishing  Customer Complaint
# 5          6            8202      Card Cloning            AI Alert
# 6          7              12          Phishing            AI Alert
# 7          8            8205    Identity Theft       Manual Review
# 8          9              14          Phishing  Customer Complaint
# 9         10              15    Identity Theft  Customer Complaint
# 10        11              16          Smishing       Manual Review
# 11        12            8207           Vishing  Customer Complaint
# 12        13              21          Phishing       Manual Review
# 13        14              22          Smishing       Manual Review
# 14        15              24  Account Takeover       Manual Review
# 15        16            8216    Identity Theft            AI Alert
# 16        17            8220          Smishing  Customer Complaint
# 17        18              33          Phishing            AI Alert
# 18        19            8226          Smishing       Manual Review
# 19        20              34           Vishing            AI Alert
# 20        21            8227          Phishing            AI Alert
# 21        22              40  Chargeback Fraud            AI Alert
# 22        23              41  Account Takeover  Customer Complaint
# 23        24              42           Vishing       Manual Review
# 24        25            8235           Vishing  Customer Complaint
#
#    report_date resolution_status  loss_amount
# 0   2024-02-17            Closed      2911.34
# 1   2019-06-25     Investigating      5331.17
# 2   2020-09-14          Resolved     28211.42
# 3   2024-06-29          Resolved     10280.88
# 4   2020-12-31            Closed      5322.88
# 5   2023-07-25          Resolved     23506.53
# 6   2024-03-18            Closed     12936.15
# 7   2025-02-16          Resolved     19689.27
# 8   2023-04-14     Investigating     14998.51
# 9   2024-07-26            Closed        82.03
# 10  2025-08-10            Closed     34607.74
# 11  2024-01-06            Closed      2853.71
# 12  2021-10-26            Closed     24778.54
# 13  2023-10-15            Closed      2950.03
# 14  2025-03-22            Closed      5668.51
# 15  2019-05-28            Closed       838.63
# 16  2024-09-27          Resolved       171.05
# 17  2022-09-20     Investigating      9386.17
# 18  2024-01-24            Closed     22982.83
# 19  2019-01-26          Resolved       235.31
# 20  2020-12-14     Investigating     11581.27
# 21  2022-04-13     Investigating      1257.06
# 22  2025-02-02            Closed      8758.75
# 23  2024-04-08          Resolved       910.11
# 24  2023-01-17     Investigating     16652.36

# %%
df.dtypes
# Out:
# fraud_id                      int64
# transaction_id                int64
# fraud_type                   object
# detection_method             object
# report_date          datetime64[ns]
# resolution_status            object
# loss_amount                 float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# fraud_id             0
# transaction_id       0
# fraud_type           0
# detection_method     0
# report_date          0
# resolution_status    0
# loss_amount          0
# dtype: int64

# %%
df.to_csv(r"C:\Users\swath\Downloads\fraud_case.csv" , index=False)

# %%
# Out:
# Empty DataFrame
# Columns: [fraud_id, transaction_id, fraud_type, detection_method, report_date, resolution_status, loss_amount]
# Index: []

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# !pip install fuzzywuzzy python-Levenshtein
from fuzzywuzzy import process
# Out:
# Requirement already satisfied: fuzzywuzzy in c:\users\swath\downloads\python\lib\site-packages (0.18.0)
# Requirement already satisfied: python-Levenshtein in c:\users\swath\downloads\python\lib\site-packages (0.27.1)
# Requirement already satisfied: Levenshtein==0.27.1 in c:\users\swath\downloads\python\lib\site-packages (from python-Levenshtein) (0.27.1)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.9.0 in c:\users\swath\downloads\python\lib\site-packages (from Levenshtein==0.27.1->python-Levenshtein) (3.14.1)

# %%
df= pd.read_csv('branch_dim.csv')

# %%
df.shape
# Out:
# (200, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   branch_id    200 non-null    int64
#  1   branch_name  200 non-null    object
#  2   city         200 non-null    object
#  3   state        200 non-null    object
#  4   region       188 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 7.9+ KB

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      branch_id             branch_name        city             state  region
# 0            1     Jaipur North Branch      Jaipur         Rajasthan   oNrth
# 1            2   Bengaluru East Branch   Bengaluru       Maharashtra    West
# 2            3      Thane South Branch       thane           haryana   North
# 3            4    Srinagar West Branch    Srinagar            Odisha    East
# 4            5  Vijayawada East Branch  Vijayawada    Madhya Pradesh    West
# ..         ...                     ...         ...               ...     ...
# 195        196  Hyderabad South Branch   Hyderabad           Mizoram    East
# 196        197     Nashik North Branch      Nashik        Chandigarh   North
# 197        198     Chennai East Branch     Chennai  Himachal Pradesh   Norht
# 198        199     Mumbai South Branch      Mumbai           Gujarat     NaN
# 199        200      Rajkot East Branch      Rajkot        CHANDIGARH   North
#
# [200 rows x 5 columns]>

# %%
df.head()
# Out:
#    branch_id             branch_name        city           state  region
# 0          1     Jaipur North Branch      Jaipur       Rajasthan   oNrth
# 1          2   Bengaluru East Branch   Bengaluru     Maharashtra    West
# 2          3      Thane South Branch       thane         haryana   North
# 3          4    Srinagar West Branch    Srinagar          Odisha    East
# 4          5  Vijayawada East Branch  Vijayawada  Madhya Pradesh    West

# %%
df.isnull().sum()
# Out:
# branch_id       0
# branch_name     0
# city            0
# state           0
# region         12
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# clean city names (this alone will fix 'thane', 'LUDHIANA', ' mumbai ', etc.)
df['city'] = df['city'].astype(str).str.strip().str.title()

# %%
df['city'].unique()
# Out:
# array(['Jaipur', 'Bengaluru', 'Thane', 'Srinagar', 'Vijayawada',
#        'Ludhiana', 'Chennai', 'Surat', 'Ahmedabad', 'Nashik', 'Hyderabad',
#        'Lucknow', 'Mumbai', 'Pune', 'Varanasi', 'Agra', 'Indore',
#        'Madurai', 'Kochi', 'Nagpur', 'Ranchi', 'Aurangabad', 'Mysuru',
#        'Kanpur', 'Kolkata', 'Ghaziabad', 'Delhi', 'Visakhapatnam',
#        'Bhopal', 'Rajkot', 'Patna', 'Vadodara', 'Guwahati', 'Coimbatore'],
#       dtype=object)

# %%
city_state_map = {
    'Jaipur': 'Rajasthan',
    'Bengaluru': 'Karnataka',
    'Thane': 'Maharashtra',
    'Srinagar': 'Jammu & Kashmir',
    'Vijayawada': 'Andhra Pradesh',
    'Ludhiana': 'Punjab',
    'Chennai': 'Tamil Nadu',
    'Surat': 'Gujarat',
    'Ahmedabad': 'Gujarat',
    'Nashik': 'Maharashtra',
    'Hyderabad': 'Telangana',
    'Lucknow': 'Uttar Pradesh',
    'Mumbai': 'Maharashtra',
    'Pune': 'Maharashtra',
    'Varanasi': 'Uttar Pradesh',
    'Agra': 'Uttar Pradesh',
    'Indore': 'Madhya Pradesh',
    'Madurai': 'Tamil Nadu',
    'Kochi': 'Kerala',
    'Nagpur': 'Maharashtra',
    'Ranchi': 'Jharkhand',
    'Aurangabad': 'Maharashtra',
    'Mysuru': 'Karnataka',
    'Kanpur': 'Uttar Pradesh',
    'Kolkata': 'West Bengal',
    'Ghaziabad': 'Uttar Pradesh',
    'Delhi': 'Delhi',
    'Visakhapatnam': 'Andhra Pradesh',
    'Bhopal': 'Madhya Pradesh',
    'Rajkot': 'Gujarat',
    'Patna': 'Bihar',
    'Vadodara': 'Gujarat',
    'Guwahati': 'Assam',
    'Coimbatore': 'Tamil Nadu'
}

df['state'] = df['city'].map(city_state_map)

# %%
df['city'].unique()
# Out:
# array(['Jaipur', 'Bengaluru', 'Thane', 'Srinagar', 'Vijayawada',
#        'Ludhiana', 'Chennai', 'Surat', 'Ahmedabad', 'Nashik', 'Hyderabad',
#        'Lucknow', 'Mumbai', 'Pune', 'Varanasi', 'Agra', 'Indore',
#        'Madurai', 'Kochi', 'Nagpur', 'Ranchi', 'Aurangabad', 'Mysuru',
#        'Kanpur', 'Kolkata', 'Ghaziabad', 'Delhi', 'Visakhapatnam',
#        'Bhopal', 'Rajkot', 'Patna', 'Vadodara', 'Guwahati', 'Coimbatore'],
#       dtype=object)

# %%
df['region'].unique()
# Out:
# array(['oNrth', 'West', ' North', 'East', 'North', nan, 'South', ' East',
#        'EAST', '  North  ', 'WEST', 'eWst', 'Eats', 'West ', 'South ',
#        'Nroth', ' West', 'SOUTH', 'Esat', 'NORTH', 'south', 'oSuth',
#        'Norht', '  East  ', '  South  '], dtype=object)

# %%
df['region'] = None

# %%
state_region_map = {
    'Rajasthan': 'North',
    'Uttar Pradesh': 'North',
    'Delhi': 'North',
    'Punjab': 'North',
    'Jammu & Kashmir': 'North',

    'Tamil Nadu': 'South',
    'Kerala': 'South',
    'Karnataka': 'South',
    'Andhra Pradesh': 'South',
    'Telangana': 'South',

    'Maharashtra': 'West',
    'Gujarat': 'West',

    'Bihar': 'East',
    'Jharkhand': 'East',
    'West Bengal': 'East',
    'Assam': 'East'
}

df['region'] = df['state'].map(state_region_map)

# %%
df['region'].unique()
# Out:
# array(['North', 'South', 'West', nan, 'East'], dtype=object)

# %%
df.head(67)
# Out:
#     branch_id                branch_name           city            state  \
# 0           1        Jaipur North Branch         Jaipur        Rajasthan
# 1           2      Bengaluru East Branch      Bengaluru        Karnataka
# 2           3         Thane South Branch          Thane      Maharashtra
# 3           4       Srinagar West Branch       Srinagar  Jammu & Kashmir
# 4           5     Vijayawada East Branch     Vijayawada   Andhra Pradesh
# ..        ...                        ...            ...              ...
# 62         63  Visakhapatnam West Branch  Visakhapatnam   Andhra Pradesh
# 63         64      Ahmedabad East Branch      Ahmedabad          Gujarat
# 64         65           Agra East Branch           Agra    Uttar Pradesh
# 65         66        Indore South Branch         Indore   Madhya Pradesh
# 66         67      Ghaziabad Main Branch      Ghaziabad    Uttar Pradesh
#
#    region
# 0   North
# 1   South
# 2    West
# 3   North
# 4   South
# ..    ...
# 62  South
# 63   West
# 64  North
# 65    NaN
# 66  North
#
# [67 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# branch_id       0
# branch_name     0
# city            0
# state           0
# region         12
# dtype: int64

# %%
df.dtypes
# Out:
# branch_id       int64
# branch_name    object
# city           object
# state          object
# region         object
# dtype: object

# %%
df[df['region'].isna()]['state'].unique()
# Out:
# array(['Madhya Pradesh'], dtype=object)

# %%
state_region_map = {
    # North
    'Rajasthan': 'North',
    'Uttar Pradesh': 'North',
    'Delhi': 'North',
    'Punjab': 'North',
    'Jammu & Kashmir': 'North',

    # South
    'Tamil Nadu': 'South',
    'Kerala': 'South',
    'Karnataka': 'South',
    'Andhra Pradesh': 'South',
    'Telangana': 'South',

    # West
    'Maharashtra': 'West',
    'Gujarat': 'West',
    'Madhya Pradesh': 'West',   # ⭐ ADD THIS LINE

    # East
    'Bihar': 'East',
    'Jharkhand': 'East',
    'West Bengal': 'East',
    'Assam': 'East'
}

# %%
df['region'] = df['state'].map(state_region_map)

# %%
df['region'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.head(60)
# Out:
#     branch_id                 branch_name           city            state  \
# 0           1         Jaipur North Branch         Jaipur        Rajasthan
# 1           2       Bengaluru East Branch      Bengaluru        Karnataka
# 2           3          Thane South Branch          Thane      Maharashtra
# 3           4        Srinagar West Branch       Srinagar  Jammu & Kashmir
# 4           5      Vijayawada East Branch     Vijayawada   Andhra Pradesh
# 5           6     Ludhiana Central Branch       Ludhiana           Punjab
# 6           7         Chennai West Branch        Chennai       Tamil Nadu
# 7           8          Surat South Branch          Surat          Gujarat
# 8           9       Ludhiana South Branch       Ludhiana           Punjab
# 9          10       Ahmedabad West Branch      Ahmedabad          Gujarat
# 10         11         Nashik South Branch         Nashik      Maharashtra
# 11         12      Hyderabad South Branch      Hyderabad        Telangana
# 12         13        Lucknow South Branch        Lucknow    Uttar Pradesh
# 13         14          Nashik Main Branch         Nashik      Maharashtra
# 14         15          Mumbai Main Branch         Mumbai      Maharashtra
# 15         16            Pune West Branch           Pune      Maharashtra
# 16         17     Varanasi Central Branch       Varanasi    Uttar Pradesh
# 17         18            Agra East Branch           Agra    Uttar Pradesh
# 18         19         Indore North Branch         Indore   Madhya Pradesh
# 19         20         Madurai Main Branch        Madurai       Tamil Nadu
# 20         21          Kochi North Branch          Kochi           Kerala
# 21         22      Chennai Central Branch        Chennai       Tamil Nadu
# 22         23         Agra Central Branch           Agra    Uttar Pradesh
# 23         24         Nagpur North Branch         Nagpur      Maharashtra
# 24         25         Ranchi North Branch         Ranchi        Jharkhand
# 25         26            Agra Main Branch           Agra    Uttar Pradesh
# 26         27          Surat South Branch          Surat          Gujarat
# 27         28        Chennai South Branch        Chennai       Tamil Nadu
# 28         29            Pune East Branch           Pune      Maharashtra
# 29         30        Kochi Central Branch          Kochi           Kerala
# 30         31      Aurangabad Main Branch     Aurangabad      Maharashtra
# 31         32        Ludhiana West Branch       Ludhiana           Punjab
# 32         33         Mysuru South Branch         Mysuru        Karnataka
# 33         34          Kanpur Main Branch         Kanpur    Uttar Pradesh
# 34         35         Kolkata Main Branch        Kolkata      West Bengal
# 35         36       Ahmedabad East Branch      Ahmedabad          Gujarat
# 36         37          Kochi North Branch          Kochi           Kerala
# 37         38          Ranchi Main Branch         Ranchi        Jharkhand
# 38         39       Ghaziabad West Branch      Ghaziabad    Uttar Pradesh
# 39         40           Pune South Branch           Pune      Maharashtra
# 40         41        Lucknow South Branch        Lucknow    Uttar Pradesh
# 41         42          Delhi South Branch          Delhi            Delhi
# 42         43       Ahmedabad Main Branch      Ahmedabad          Gujarat
# 43         44           Pune North Branch           Pune      Maharashtra
# 44         45      Madurai Central Branch        Madurai       Tamil Nadu
# 45         46  Visakhapatnam South Branch  Visakhapatnam   Andhra Pradesh
# 46         47            Pune West Branch           Pune      Maharashtra
# 47         48       Hyderabad East Branch      Hyderabad        Telangana
# 48         49          Kanpur Main Branch         Kanpur    Uttar Pradesh
# 49         50          Mysuru West Branch         Mysuru        Karnataka
# 50         51          Mysuru West Branch         Mysuru        Karnataka
# 51         52            Pune West Branch           Pune      Maharashtra
# 52         53       Hyderabad West Branch      Hyderabad        Telangana
# 53         54      Bengaluru North Branch      Bengaluru        Karnataka
# 54         55         Bhopal North Branch         Bhopal   Madhya Pradesh
# 55         56       Rajkot Central Branch         Rajkot          Gujarat
# 56         57         Jaipur North Branch         Jaipur        Rajasthan
# 57         58         Rajkot North Branch         Rajkot          Gujarat
# 58         59       Mysuru Central Branch         Mysuru        Karnataka
# 59         60          Thane North Branch          Thane      Maharashtra
#
#    region
# 0   North
# 1   South
# 2    West
# 3   North
# 4   South
# 5   North
# 6   South
# 7    West
# 8   North
# 9    West
# 10   West
# 11  South
# 12  North
# 13   West
# 14   West
# 15   West
# 16  North
# 17  North
# 18   West
# 19  South
# 20  South
# 21  South
# 22  North
# 23   West
# 24   East
# 25  North
# 26   West
# 27  South
# 28   West
# 29  South
# 30   West
# 31  North
# 32  South
# 33  North
# 34   East
# 35   West
# 36  South
# 37   East
# 38  North
# 39   West
# 40  North
# 41  North
# 42   West
# 43   West
# 44  South
# 45  South
# 46   West
# 47  South
# 48  North
# 49  South
# 50  South
# 51   West
# 52  South
# 53  South
# 54   West
# 55   West
# 56  North
# 57   West
# 58  South
# 59   West

# %%
df.dtypes
# Out:
# branch_id       int64
# branch_name    object
# city           object
# state          object
# region         object
# dtype: object

# %%
df.isnull().sum()
# Out:
# branch_id      0
# branch_name    0
# city           0
# state          0
# region         0
# dtype: int64

# %%
df.to_csv(r"C:\Users\swath\Downloads\branch.csv", index=False)

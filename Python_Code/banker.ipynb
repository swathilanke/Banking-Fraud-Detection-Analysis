# %%
import pandas as pd
import numpy as np

# !pip install fuzzywuzzy python-Levenshtein
from fuzzywuzzy import process
# Out:
# Requirement already satisfied: fuzzywuzzy in c:\users\swath\downloads\python\lib\site-packages (0.18.0)
# Requirement already satisfied: python-Levenshtein in c:\users\swath\downloads\python\lib\site-packages (0.27.1)
# Requirement already satisfied: Levenshtein==0.27.1 in c:\users\swath\downloads\python\lib\site-packages (from python-Levenshtein) (0.27.1)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.9.0 in c:\users\swath\downloads\python\lib\site-packages (from Levenshtein==0.27.1->python-Levenshtein) (3.14.1)

# %%
df = pd.read_csv('banker_dim.csv')

# %%
df.shape
# Out:
# (800, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   banker_id         800 non-null    int64
#  1   name              800 non-null    object
#  2   role              800 non-null    object
#  3   branch_id         800 non-null    int64
#  4   experience_years  800 non-null    int64
# dtypes: int64(3), object(2)
# memory usage: 31.4+ KB

# %%
df.head()
# Out:
#    banker_id           name                  role  branch_id  experience_years
# 0          1    Aarav Singh  Relationship Manager        101                 0
# 1          2  Vihaan Kapoor          Loan Officer         31                 8
# 2          3    Aadhya Jain  Relationship Manager        125                 3
# 3          4  Aditya Sharma        rBanch Manager        109                11
# 4          5   Ananya Gupta          Data Analyst        182                -1

# %%
df.isnull().sum()
# Out:
# banker_id           0
# name                0
# role                0
# branch_id           0
# experience_years    0
# dtype: int64

# %%
df.dtypes
# Out:
# banker_id            int64
# name                object
# role                object
# branch_id            int64
# experience_years     int64
# dtype: object

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#remove extra spaces, fix casing, handle weird characters.
# basic name cleaning
df['name'] = (df['name'].astype(str).str.strip().str.replace(r'\s+', ' ', regex=True).str.title())

# %%
#Fix obvious role typos (like rBranch Manager)
df['role'].unique()
# Out:
# array(['Relationship Manager', 'Loan Officer', 'rBanch Manager',
#        'Data Analyst', 'Branch Manager', 'Fraud Analyst',
#        'relationship manager', 'Teller', 'Data Analyst ',
#        'RELATIONSHIP MANAGER', 'teller', 'Dtaa Analyst',
#        '  Data Analyst  ', 'Tleler', 'Relationship aMnager',
#        ' Fraud Analyst', 'Data Analyts', 'Loa nOfficer', 'Loan fOficer',
#        ' Loan Officer', 'FRAUD ANALYST', '  Fraud Analyst  ',
#        '  Branch Manager  ', 'Fraud Anlayst', 'Teller ', 'Fraud Analyst ',
#        ' Data Analyst', 'TELLER', 'Fraud nAalyst',
#        ' Relationship Manager', 'Barnch Manager',
#        '  Relationship Manager  ', ' Branch Mnaager', 'Data Aanlyst',
#        'Lona Officer', 'Telelr', 'BRANCH MANAGER', ' Branch Manager',
#        'Data Anlayst', 'Loan Officer ', 'Reltaionship Manager',
#        'Fraud Aanlyst', 'Relationship Manager ', 'loan officer',
#        'Laon Officer', 'fraud analyst', 'erlationship manager',
#        'Data nAalyst', 'data analyst', 'Farud Analyst', 'LOAN OFFICER',
#        'DATA ANALYST', 'eRlationship Manager', ' Teller', '  Teller  ',
#        'Relationship Mnaager', 'Branch Maanger', 'FraudA nalyst',
#        'Fraud Naalyst', 'Bracnh Manager', '  Loan Officer  ', 'telelr',
#        'Daat Analyst', 'Relationshpi Manager', 'Relationhsip Manager',
#        'oLan Officer', 'Branch Manager ', 'Branch aMnager',
#        'LoanO fficer', 'Branch Mnaager', 'Tellre', 'Branc hManager',
#        'Data Anaylst', 'Relatiosnhip Manager ', 'eTller', 'Data Analsyt',
#        'Loan Ofifcer'], dtype=object)

# %%
#Define clean valid roles
valid_roles = [
    'Branch Manager',
    'Relationship Manager',
    'Data Analyst',
    'Fraud Analyst',
    'Loan Officer',
    'Teller'
]

# %%
#Normalize dirty roles
df['role_clean'] = (df['role'].astype(str).str.strip().str.lower())

# %%
#Fuzzy Match to Correct Role
def fuzzy_fix_role(text):
    match, score = process.extractOne(text, [r.lower() for r in valid_roles])
    # score is similarity (0–100)
    if score >= 70:   # threshold
        # return properly formatted role
        for vr in valid_roles:
            if vr.lower() == match:
                return vr
    return text.title()

# %%
df['role'] = df['role_clean'].apply(fuzzy_fix_role)

# %%
df.head(25)
# Out:
#     banker_id            name                  role  branch_id  \
# 0           1     Aarav Singh  Relationship Manager        101
# 1           2   Vihaan Kapoor          Loan Officer         31
# 2           3     Aadhya Jain  Relationship Manager        125
# 3           4   Aditya Sharma        Branch Manager        109
# 4           5    Ananya Gupta          Data Analyst        182
# 5           6     Rohan Singh          Data Analyst         92
# 6           7       Kavya Das        Branch Manager        130
# 7           8    Vivaan Naidu  Relationship Manager         26
# 8           9    Aadhya Gowda  Relationship Manager        172
# 9          10   Vihaan Chopra          Loan Officer         29
# 10         11  Krishna Shetty          Loan Officer        141
# 11         12   Sanjana Menon         Fraud Analyst        130
# 12         13  Sanjana Chopra          Data Analyst         77
# 13         14    Ananya Verma        Branch Manager        114
# 14         15     Rahul Yadav  Relationship Manager         37
# 15         16      Arjun Bose  Relationship Manager         63
# 16         17    Vivaan Menon         Fraud Analyst        164
# 17         18       Sai Singh          Data Analyst        187
# 18         19     Rahul Gupta        Branch Manager          3
# 19         20   Krishna Patel  Relationship Manager         65
# 20         21  Arjun Banerjee        Branch Manager        181
# 21         22     Ishita Iyer          Data Analyst         21
# 22         23     Ishita Bose  Relationship Manager        190
# 23         24     Rahul Menon  Relationship Manager        169
# 24         25    Rohan Sharma  Relationship Manager        147
#
#     experience_years            role_clean
# 0                  0  relationship manager
# 1                  8          loan officer
# 2                  3  relationship manager
# 3                 11        rbanch manager
# 4                 -1          data analyst
# 5                  6          data analyst
# 6                  7        branch manager
# 7                  2  relationship manager
# 8                  8  relationship manager
# 9                  6          loan officer
# 10                14          loan officer
# 11                12         fraud analyst
# 12                11          data analyst
# 13                 8        branch manager
# 14                13  relationship manager
# 15                 8  relationship manager
# 16                10         fraud analyst
# 17                 8          data analyst
# 18                 6        branch manager
# 19                 5  relationship manager
# 20                 0        branch manager
# 21                 0          data analyst
# 22                 5  relationship manager
# 23                16  relationship manager
# 24                 6  relationship manager

# %%
df['role'].unique()
# Out:
# array(['Relationship Manager', 'Loan Officer', 'Branch Manager',
#        'Data Analyst', 'Fraud Analyst', 'Teller'], dtype=object)

# %%
df.drop(columns=['role_clean'], inplace=True)

# %%
df.dtypes
# Out:
# banker_id            int64
# name                object
# role                object
# branch_id            int64
# experience_years     int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# banker_id           0
# name                0
# role                0
# branch_id           0
# experience_years    0
# dtype: int64

# %%
#Convert negative experience years to 0
#This keeps the data complete with no missing values.
df['experience_years'] = df['experience_years'].clip(lower=0)

# %%
df.head(30)
# Out:
#     banker_id              name                  role  branch_id  \
# 0           1       Aarav Singh  Relationship Manager        101
# 1           2     Vihaan Kapoor          Loan Officer         31
# 2           3       Aadhya Jain  Relationship Manager        125
# 3           4     Aditya Sharma        Branch Manager        109
# 4           5      Ananya Gupta          Data Analyst        182
# 5           6       Rohan Singh          Data Analyst         92
# 6           7         Kavya Das        Branch Manager        130
# 7           8      Vivaan Naidu  Relationship Manager         26
# 8           9      Aadhya Gowda  Relationship Manager        172
# 9          10     Vihaan Chopra          Loan Officer         29
# 10         11    Krishna Shetty          Loan Officer        141
# 11         12     Sanjana Menon         Fraud Analyst        130
# 12         13    Sanjana Chopra          Data Analyst         77
# 13         14      Ananya Verma        Branch Manager        114
# 14         15       Rahul Yadav  Relationship Manager         37
# 15         16        Arjun Bose  Relationship Manager         63
# 16         17      Vivaan Menon         Fraud Analyst        164
# 17         18         Sai Singh          Data Analyst        187
# 18         19       Rahul Gupta        Branch Manager          3
# 19         20     Krishna Patel  Relationship Manager         65
# 20         21    Arjun Banerjee        Branch Manager        181
# 21         22       Ishita Iyer          Data Analyst         21
# 22         23       Ishita Bose  Relationship Manager        190
# 23         24       Rahul Menon  Relationship Manager        169
# 24         25      Rohan Sharma  Relationship Manager        147
# 25         26  Sanjana Banerjee                Teller         40
# 26         27       Aarav Verma                Teller        152
# 27         28       Priya Naidu          Data Analyst         52
# 28         29       Arjun Patel  Relationship Manager         68
# 29         30        Vivaan Das                Teller         64
#
#     experience_years
# 0                  0
# 1                  8
# 2                  3
# 3                 11
# 4                  0
# 5                  6
# 6                  7
# 7                  2
# 8                  8
# 9                  6
# 10                14
# 11                12
# 12                11
# 13                 8
# 14                13
# 15                 8
# 16                10
# 17                 8
# 18                 6
# 19                 5
# 20                 0
# 21                 0
# 22                 5
# 23                16
# 24                 6
# 25                 3
# 26                 0
# 27                 0
# 28                 8
# 29                 4

# %%
df.to_csv(r"C:\Users\swath\Downloads\banker.csv", index=False)

# %%
df.shape
# Out:
# (800, 5)

# %%
import pandas as pd
import numpy as np

# !pip install fuzzywuzzy python-Levenshtein
from fuzzywuzzy import process
# Out:
# Requirement already satisfied: fuzzywuzzy in c:\users\swath\downloads\python\lib\site-packages (0.18.0)
# Requirement already satisfied: python-Levenshtein in c:\users\swath\downloads\python\lib\site-packages (0.27.1)
# Requirement already satisfied: Levenshtein==0.27.1 in c:\users\swath\downloads\python\lib\site-packages (from python-Levenshtein) (0.27.1)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.9.0 in c:\users\swath\downloads\python\lib\site-packages (from Levenshtein==0.27.1->python-Levenshtein) (3.14.1)

# %%
df = pd.read_csv('fact_loan.csv')

# %%
df.shape
# Out:
# (3520, 7)

# %%
df.head()
# Out:
#    loan_id  customer_id  loan_type loan_amount  issue_date loan_status  \
# 0        1         4015   Business   558811.91  2022-04-21     Default
# 1        2         4007  Education   370193.71  2014-05-28      Closed
# 2        3         4028   Business   344548.54  2025-09-29      Active
# 3        4         4035       Home   692764.55  2015-01-13      Closed
# 4        5         4040  Education   746639.94  2025-01-07      Closed
#
#   is_fraud
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
df.isnull().sum()
# Out:
# loan_id        0
# customer_id    0
# loan_type      0
# loan_amount    0
# issue_date     0
# loan_status    0
# is_fraud       0
# dtype: int64

# %%
df.dtypes
# Out:
# loan_id         int64
# customer_id     int64
# loan_type      object
# loan_amount    object
# issue_date     object
# loan_status    object
# is_fraud       object
# dtype: object

# %%
df.duplicated().sum()
# Out:
# np.int64(20)

# %%
df.drop_duplicates()
# Out:
#       loan_id  customer_id  loan_type loan_amount    issue_date loan_status  \
# 0           1         4015   Business   558811.91    2022-04-21     Default
# 1           2         4007  Education   370193.71    2014-05-28      Closed
# 2           3         4028   Business   344548.54    2025-09-29      Active
# 3           4         4035       Home   692764.55    2015-01-13      Closed
# 4           5         4040  Education   746639.94    2025-01-07      Closed
# ...       ...          ...        ...         ...           ...         ...
# 3495     3496         4036    Vehicle    325198.6  Aug 26, 2016      Closed
# 3496     3497         4020  Education   856410.24    2016-09-22      Active
# 3497     3498         4022       Gold   162079.85    2013/06/20      Active
# 3498     3499         4021       Home    623729.6    2019-03-29     Default
# 3499     3500         4024       Home   418400.57    2019/10/06     Default
#
#      is_fraud
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 3495        0
# 3496        0
# 3497        0
# 3498        0
# 3499        0
#
# [3500 rows x 7 columns]

# %%
# 1. Fix issue_date - convert to datetime
df['issue_date'] = pd.to_datetime(df['issue_date'], format='mixed', dayfirst=True)

# %%
df['issue_date'] = pd.to_datetime(df['issue_date'], errors='coerce')
df.dtypes
# Out:
# loan_id                 int64
# customer_id             int64
# loan_type              object
# loan_amount            object
# issue_date     datetime64[ns]
# loan_status            object
# is_fraud               object
# dtype: object

# %%
df.isnull().sum()
# Out:
# loan_id        0
# customer_id    0
# loan_type      0
# loan_amount    0
# issue_date     0
# loan_status    0
# is_fraud       0
# dtype: int64

# %%
df['loan_type'] = (df['loan_type'].astype(str).str.strip().str.lower())

# %%
# 2. Correct categories
valid_loan_types = [
    'business',
    'education',
    'home',
    'vehicle',
    'gold',
    'personal'
]

# %%
# 3. Fuzzy match function
def correct_loan_type(x):
    match, score = process.extractOne(x, valid_loan_types)
    return match if score >= 60 else x

# %%
# 4. Apply clean
df['loan_type'] = df['loan_type'].apply(correct_loan_type)

# %%
#5. Format properly
df['loan_type'] = df['loan_type'].replace({
    'business': 'Business',
    'education': 'Education',
    'home': 'Home',
    'vehicle': 'Vehicle',
    'gold': 'Gold',
    'personal': 'Personal'
})

# %%
print(df['loan_type'].value_counts())
print(df['loan_type'].unique())
df.dtypes
# Out:
# loan_type
# Business     609
# Education    602
# Personal     589
# Home         583
# Vehicle      577
# Gold         560
# Name: count, dtype: int64
# ['Business' 'Education' 'Home' 'Vehicle' 'Gold' 'Personal']
# loan_id                 int64
# customer_id             int64
# loan_type              object
# loan_amount            object
# issue_date     datetime64[ns]
# loan_status            object
# is_fraud               object
# dtype: object

# %%
# Basic clean: remove spaces + lowercase
df['loan_status'] = df['loan_status'].astype(str).str.strip().str.lower()

# %%
# Fix to correct categories
df['loan_status'] = df['loan_status'].replace({
    'active': 'Active',
    'closed': 'Closed',
    'default': 'Default'
})

# %%
print(df['loan_status'].value_counts())
print(df['loan_status'].unique())
# Out:
# loan_status
# Closed     1190
# Default    1187
# Active     1143
# Name: count, dtype: int64
# ['Default' 'Closed' 'Active']

# %%
df.head(373)
# Out:
#      loan_id  customer_id  loan_type loan_amount issue_date loan_status  \
# 0          1         4015   Business   558811.91 2022-04-21     Default
# 1          2         4007  Education   370193.71 2014-05-28      Closed
# 2          3         4028   Business   344548.54 2025-09-29      Active
# 3          4         4035       Home   692764.55 2015-01-13      Closed
# 4          5         4040  Education   746639.94 2025-01-07      Closed
# ..       ...          ...        ...         ...        ...         ...
# 368      369         4040  Education   178550.38 2015-05-31      Active
# 369      370         4028   Personal   648216.39 2023-10-08     Default
# 370      371         4036    Vehicle    84719.13 2014-06-25      Active
# 371      372         4002   Personal   425344.53 2023-03-24     Default
# 372      373         4009   Business    531671.3 2014-06-04     Default
#
#     is_fraud
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ..       ...
# 368        0
# 369        0
# 370        0
# 371        0
# 372        0
#
# [373 rows x 7 columns]

# %%
# 5. Fix amount - remove currency symbols and commas
df['loan_amount'] = df['loan_amount'].astype(str).str.replace('₹', '').str.replace(',', '')
df['loan_amount'] = df['loan_amount'].astype(float)
df.dtypes
# Out:
# loan_id                 int64
# customer_id             int64
# loan_type              object
# loan_amount           float64
# issue_date     datetime64[ns]
# loan_status            object
# is_fraud               object
# dtype: object

# %%
df['is_fraud'] = df['is_fraud'].astype(str).str.strip().str.lower()

# %%
#(Handles values: “yes/no”, “true/false”, “1/0”, mixed spellings)
df['is_fraud'] = df['is_fraud'].replace({
    'yes': 1,
    'y': 1,
    'true': 1,
    '1': 1,
    'fraud': 1,
    'no': 0,
    'n': 0,
    'false': 0,
    '0': 0,
    'not fraud': 0
})
# Out:
# C:\Users\swath\AppData\Local\Temp\ipykernel_332\2181811835.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['is_fraud'] = df['is_fraud'].replace({

# %%
df['is_fraud'] = df['is_fraud'].astype(int)
df.dtypes
# Out:
# loan_id                 int64
# customer_id             int64
# loan_type              object
# loan_amount           float64
# issue_date     datetime64[ns]
# loan_status            object
# is_fraud                int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# loan_id        0
# customer_id    0
# loan_type      0
# loan_amount    0
# issue_date     0
# loan_status    0
# is_fraud       0
# dtype: int64

# %%
df.to_csv(r"C:\Users\swath\Downloads\loan.csv" , index=False)

# %%
df.shape
# Out:
# (3520, 7)

# %%
df.duplicated('loan_id').sum()
# Out:
# np.int64(20)

# %%
df[df.duplicated('loan_id', keep=False)].sort_values('loan_id')
# Out:
#       loan_id  customer_id  loan_type  loan_amount issue_date loan_status  \
# 176       177         4035   Business    526196.11 2019-09-29      Closed
# 3515      177         4035   Business    526196.11 2019-09-29      Closed
# 3519      394         4038       Gold   -165622.90 2021-01-26      Active
# 393       394         4038       Gold   -165622.90 2021-01-26      Active
# 438       439         4003   Business    650146.53 2025-09-16      Closed
# 3503      439         4003   Business    650146.53 2025-09-16      Closed
# 490       491         4024   Business    715386.03 2021-02-20      Active
# 3514      491         4024   Business    715386.03 2021-02-20      Active
# 3512      957         4028       Home    343422.86 2014-04-17      Closed
# 956       957         4028       Home    343422.86 2014-04-17      Closed
# 1044     1045         4019  Education     79497.92 2018-10-06      Closed
# 3517     1045         4019  Education     79497.92 2018-10-06      Closed
# 3509     1250         4031       Gold    352799.41 2023-12-25      Active
# 1249     1250         4031       Gold    352799.41 2023-12-25      Active
# 1425     1426         4006  Education    399070.44 2024-03-15     Default
# 3510     1426         4006  Education    399070.44 2024-03-15     Default
# 3502     1490         4008   Personal    465494.38 2013-12-21      Closed
# 1489     1490         4008   Personal    465494.38 2013-12-21      Closed
# 3506     1524         4001       Home    912821.52 2016-07-13      Active
# 1523     1524         4001       Home    912821.52 2016-07-13      Active
# 3511     1573         4020    Vehicle    297541.10 2025-09-27      Active
# 1572     1573         4020    Vehicle    297541.10 2025-09-27      Active
# 3505     2082         4010   Personal    255418.99 2019-05-10      Closed
# 2081     2082         4010   Personal    255418.99 2019-05-10      Closed
# 3507     2555         4020  Education     74662.74 2022-07-06      Active
# 2554     2555         4020  Education     74662.74 2022-07-06      Active
# 3518     2718         4022    Vehicle    289162.00 2019-05-15      Active
# 2717     2718         4022    Vehicle    289162.00 2019-05-15      Active
# 3500     2772         4008   Personal    537836.37 2023-12-25      Closed
# 2771     2772         4008   Personal    537836.37 2023-12-25      Closed
# 2773     2774         4009   Business    239523.62 2024-09-22      Active
# 3516     2774         4009   Business    239523.62 2024-09-22      Active
# 2788     2789         4006       Home    307317.55 2018-03-31     Default
# 3513     2789         4006       Home    307317.55 2018-03-31     Default
# 3036     3037         4012   Personal    348078.93 2017-03-21     Default
# 3501     3037         4012   Personal    348078.93 2017-03-21     Default
# 3118     3119         4036  Education    506253.85 2019-12-22      Closed
# 3508     3119         4036  Education    506253.85 2019-12-22      Closed
# 3504     3321         4039   Personal     53983.01 2022-03-08     Default
# 3320     3321         4039   Personal     53983.01 2022-03-08     Default
#
#       is_fraud
# 176          0
# 3515         0
# 3519         0
# 393          0
# 438          0
# 3503         0
# 490          0
# 3514         0
# 3512         0
# 956          0
# 1044         0
# 3517         0
# 3509         0
# 1249         0
# 1425         0
# 3510         0
# 3502         0
# 1489         0
# 3506         0
# 1523         0
# 3511         0
# 1572         0
# 3505         0
# 2081         0
# 3507         0
# 2554         0
# 3518         0
# 2717         0
# 3500         0
# 2771         0
# 2773         0
# 3516         0
# 2788         0
# 3513         0
# 3036         0
# 3501         0
# 3118         0
# 3508         0
# 3504         0
# 3320         0

# %%
df = df.drop_duplicates(subset='loan_id', keep='first')

# %%
df.shape
# Out:
# (3500, 7)

# %%
#loan.csv → fix negative loan_amount
df['loan_amount'] = df['loan_amount'].abs()

# %%
df[df['loan_amount'] < 0]
# Out:
# Empty DataFrame
# Columns: [loan_id, customer_id, loan_type, loan_amount, issue_date, loan_status, is_fraud]
# Index: []

# %%
df.dtypes
# Out:
# loan_id                 int64
# customer_id             int64
# loan_type              object
# loan_amount           float64
# issue_date     datetime64[ns]
# loan_status            object
# is_fraud                int64
# dtype: object

# %%
df.head(179)
# Out:
#      loan_id  customer_id  loan_type  loan_amount issue_date loan_status  \
# 0          1         4015   Business    558811.91 2022-04-21     Default
# 1          2         4007  Education    370193.71 2014-05-28      Closed
# 2          3         4028   Business    344548.54 2025-09-29      Active
# 3          4         4035       Home    692764.55 2015-01-13      Closed
# 4          5         4040  Education    746639.94 2025-01-07      Closed
# ..       ...          ...        ...          ...        ...         ...
# 174      175         4007   Personal    481220.55 2018-04-07      Closed
# 175      176         4010       Home    384959.20 2024-12-10      Active
# 176      177         4035   Business    526196.11 2019-09-29      Closed
# 177      178         4035       Gold    219103.82 2024-05-20      Active
# 178      179         4040       Home    496682.88 2013-07-21     Default
#
#      is_fraud
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ..        ...
# 174         0
# 175         0
# 176         0
# 177         0
# 178         0
#
# [179 rows x 7 columns]

# %%
df.shape
# Out:
# (3500, 7)

# %%
df.to_csv(r"C:\Users\swath\Downloads\loan.csv", index=False)

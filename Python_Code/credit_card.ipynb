# %%
import pandas as pd
import numpy as np

# !pip install fuzzywuzzy python-Levenshtein
from fuzzywuzzy import process
# Out:
# Requirement already satisfied: fuzzywuzzy in c:\users\swath\downloads\python\lib\site-packages (0.18.0)
# Requirement already satisfied: python-Levenshtein in c:\users\swath\downloads\python\lib\site-packages (0.27.1)
# Requirement already satisfied: Levenshtein==0.27.1 in c:\users\swath\downloads\python\lib\site-packages (from python-Levenshtein) (0.27.1)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.9.0 in c:\users\swath\downloads\python\lib\site-packages (from Levenshtein==0.27.1->python-Levenshtein) (3.14.1)

# %%
df = pd.read_csv('fact_credit_card.csv')

# %%
df.shape
# Out:
# (5025, 6)

# %%
df.isnull().sum()
# Out:
# card_id         0
# customer_id     0
# card_type       0
# limit_amount    0
# issue_date      0
# is_active       0
# dtype: int64

# %%
df.head()
# Out:
#    card_id  customer_id   card_type limit_amount    issue_date is_active
# 0        1         4001       RPuay     19593.39    03/02/2017         1
# 1        2          544       RuPay    -42708.22    2022-12-03         1
# 2        3         4020  MasterCard    134380.06    2020-06-04         0
# 3        4         4009        Amex    111110.06  Jul 07, 2019         1
# 4        5         4029       RuPay     112894.0    2017/01/29         1

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       card_id  customer_id   card_type limit_amount    issue_date is_active
# 0           1         4001       RPuay     19593.39    03/02/2017         1
# 1           2          544       RuPay    -42708.22    2022-12-03         1
# 2           3         4020  MasterCard    134380.06    2020-06-04         0
# 3           4         4009        Amex    111110.06  Jul 07, 2019         1
# 4           5         4029       RuPay     112894.0    2017/01/29         1
# ...       ...          ...         ...          ...           ...       ...
# 5020     2593         4005  MasterCard    204267.97    13-01-2014         1
# 5021     1841         4008  MasterCard   -112088.68    2019-11-05         0
# 5022     3075         4003  MasterCard    135449.27    2019-07-27         1
# 5023     4297         4039        Visa     78413.26    2015-10-15         1
# 5024     2052         4012  MasterCard     83520.21    2023-06-29         0
#
# [5025 rows x 6 columns]>

# %%
df.describe()
# Out:
#            card_id  customer_id
# count  5025.000000  5025.000000
# mean   2499.419303  3995.563383
# std    1443.043476   251.944288
# min       1.000000   126.000000
# 25%    1250.000000  4010.000000
# 50%    2502.000000  4020.000000
# 75%    3748.000000  4030.000000
# max    5000.000000  4040.000000

# %%
df.duplicated().sum()
# Out:
# np.int64(25)

# %%
df.drop_duplicates()
# Out:
#       card_id  customer_id   card_type limit_amount    issue_date is_active
# 0           1         4001       RPuay     19593.39    03/02/2017         1
# 1           2          544       RuPay    -42708.22    2022-12-03         1
# 2           3         4020  MasterCard    134380.06    2020-06-04         0
# 3           4         4009        Amex    111110.06  Jul 07, 2019         1
# 4           5         4029       RuPay     112894.0    2017/01/29         1
# ...       ...          ...         ...          ...           ...       ...
# 4995     4996         4009        Amex    138439.95    2021-06-27         1
# 4996     4997         4025  MasterCard    197593.27    2021-05-26         1
# 4997     4998         4032       RuPay    110628.31    2024-10-30         1
# 4998     4999         4005        Amex    193948.15    2025-10-02         1
# 4999     5000         4026        Visa     83496.79    2021-12-09         0
#
# [5000 rows x 6 columns]

# %%
# 1. Fix issue_date - convert to datetime
df['issue_date'] = pd.to_datetime(df['issue_date'], format='mixed', dayfirst=True)

# %%
df['issue_date'] = pd.to_datetime(df['issue_date'], errors='coerce')
df.dtypes
# Out:
# card_id                  int64
# customer_id              int64
# card_type               object
# limit_amount            object
# issue_date      datetime64[ns]
# is_active               object
# dtype: object

# %%
df.isnull().sum()
# Out:
# card_id         0
# customer_id     0
# card_type       0
# limit_amount    0
# issue_date      0
# is_active       0
# dtype: int64

# %%
df.head(10)
# Out:
#    card_id  customer_id   card_type limit_amount issue_date is_active
# 0        1         4001       RPuay     19593.39 2017-02-03         1
# 1        2          544       RuPay    -42708.22 2022-12-03         1
# 2        3         4020  MasterCard    134380.06 2020-06-04         0
# 3        4         4009        Amex    111110.06 2019-07-07         1
# 4        5         4029       RuPay     112894.0 2017-01-29         1
# 5        6         4005        Amex     83192.61 2025-10-12         1
# 6        7         4021        Amex    206911.34 2014-05-04         1
# 7        8         4032        Amex    253629.22 2017-10-12         1
# 8        9         4040        Amex     46289.85 2020-07-09         1
# 9       10         4034        Visa    246651.17 2021-08-05         1

# %%
# 1. Basic cleaning (strip + lowercase)
df['card_type'] = (df['card_type'].astype(str).str.strip().str.lower())

# %%
# 2. Valid categories
valid_cards = [
    'visa',
    'mastercard',
    'amex',
    'rupay'
]

# %%
# 3. Fuzzy match function
def clean_card_type(x):
    match, score = process.extractOne(x, valid_cards)
    return match if score >= 60 else x

# %%
# 4. Apply correction
df['card_type'] = df['card_type'].apply(clean_card_type)

# %%
# 5. Proper formatting
df['card_type'] = df['card_type'].replace({
    'visa': 'Visa',
    'mastercard': 'MasterCard',
    'amex': 'Amex',
    'rupay': 'RuPay'
})

# %%
print(df['card_type'].value_counts())
print(df['card_type'].unique())
# Out:
# card_type
# Visa          1288
# MasterCard    1271
# RuPay         1237
# Amex          1229
# Name: count, dtype: int64
# ['RuPay' 'MasterCard' 'Amex' 'Visa']

# %%
df.isnull().sum()
# Out:
# card_id         0
# customer_id     0
# card_type       0
# limit_amount    0
# issue_date      0
# is_active       0
# dtype: int64

# %%
# 5. Fix amount - remove currency symbols and commas
df['limit_amount'] = df['limit_amount'].astype(str).str.replace('₹', '').str.replace(',', '')
df['limit_amount'] = df['limit_amount'].astype(float)
df.dtypes
# Out:
# card_id                  int64
# customer_id              int64
# card_type               object
# limit_amount           float64
# issue_date      datetime64[ns]
# is_active               object
# dtype: object

# %%
df['is_active'] = df['is_active'].astype(str).str.strip().str.lower()

# %%
df['is_active'] = df['is_active'].replace({
    '1': 1,
    'true': 1,
    'yes': 1,
    '0': 0,
    'false': 0,
    'no': 0
})
# Out:
# C:\Users\swath\AppData\Local\Temp\ipykernel_2724\409717193.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['is_active'] = df['is_active'].replace({

# %%
df['is_active'] = df['is_active'].astype(int)

# %%
df.dtypes
# Out:
# card_id                  int64
# customer_id              int64
# card_type               object
# limit_amount           float64
# issue_date      datetime64[ns]
# is_active                int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# card_id         0
# customer_id     0
# card_type       0
# limit_amount    0
# issue_date      0
# is_active       0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# card_id         0
# customer_id     0
# card_type       0
# limit_amount    0
# issue_date      0
# is_active       0
# dtype: int64

# %%
df.shape
# Out:
# (5025, 6)

# %%
df.duplicated().sum()
# Out:
# np.int64(25)

# %%
df.duplicated('card_id').sum()
# Out:
# np.int64(25)

# %%
df[df.duplicated('card_id', keep=False)].sort_values('card_id')
# Out:
#       card_id  customer_id   card_type  limit_amount issue_date  is_active
# 48         49         4019       RuPay     175681.55 2024-03-04          1
# 5001       49         4019       RuPay     175681.55 2024-03-04          1
# 230       231         4037  MasterCard     201351.84 2022-08-31          1
# 5013      231         4037  MasterCard     201351.84 2022-08-31          1
# 5002      268         4011       RuPay     100640.60 2018-12-17          1
# 267       268         4011       RuPay     100640.60 2018-12-17          1
# 5017      278         4026        Visa      98400.80 2024-01-12          1
# 277       278         4026        Visa      98400.80 2024-01-12          1
# 897       898         4038  MasterCard      94039.85 2019-01-06          1
# 5005      898         4038  MasterCard      94039.85 2019-01-06          1
# 1037     1038          967       RuPay      98057.48 2015-12-31          1
# 5009     1038          967       RuPay      98057.48 2015-12-31          1
# 5016     1191         4034        Visa     191019.07 2016-07-27          1
# 1190     1191         4034        Visa     191019.07 2016-07-27          1
# 1424     1425         4015  MasterCard      51114.11 2014-04-17          0
# 5011     1425         4015  MasterCard      51114.11 2014-04-17          0
# 5003     1600         4028  MasterCard      92797.72 2014-03-30          1
# 1599     1600         4028  MasterCard      92797.72 2014-03-30          1
# 5021     1841         4008  MasterCard    -112088.68 2019-11-05          0
# 1840     1841         4008  MasterCard    -112088.68 2019-11-05          0
# 2051     2052         4012  MasterCard      83520.21 2023-06-29          0
# 5024     2052         4012  MasterCard      83520.21 2023-06-29          0
# 5015     2528         4016        Visa     200144.43 2023-05-14          0
# 2527     2528         4016        Visa     200144.43 2023-05-14          0
# 2592     2593         4005  MasterCard     204267.97 2014-01-13          1
# 5020     2593         4005  MasterCard     204267.97 2014-01-13          1
# 5014     2626         4018  MasterCard     169020.78 2022-01-10          1
# 2625     2626         4018  MasterCard     169020.78 2022-01-10          1
# 2770     2771         4033        Visa     176702.90 2023-04-25          0
# 5018     2771         4033        Visa     176702.90 2023-04-25          0
# 5006     2894         4015        Amex     186386.71 2023-06-25          0
# 2893     2894         4015        Amex     186386.71 2023-06-25          0
# 2926     2927         4032  MasterCard      50181.45 2019-03-25          1
# 5012     2927         4032  MasterCard      50181.45 2019-03-25          1
# 5022     3075         4003  MasterCard     135449.27 2019-07-27          1
# 3074     3075         4003  MasterCard     135449.27 2019-07-27          1
# 3096     3097         4026  MasterCard     124654.49 2023-12-27          1
# 5004     3097         4026  MasterCard     124654.49 2023-12-27          1
# 3187     3188         4037        Visa     289568.29 2022-12-23          1
# 5019     3188         4037        Visa     289568.29 2022-12-23          1
# 3408     3409         4037       RuPay     148279.94 2016-09-16          1
# 5000     3409         4037       RuPay     148279.94 2016-09-16          1
# 5008     4132         4017  MasterCard     245892.41 2017-04-27          1
# 4131     4132         4017  MasterCard     245892.41 2017-04-27          1
# 4222     4223         4014        Visa     179792.36 2025-02-07          1
# 5010     4223         4014        Visa     179792.36 2025-02-07          1
# 5023     4297         4039        Visa      78413.26 2015-10-15          1
# 4296     4297         4039        Visa      78413.26 2015-10-15          1
# 4450     4451         4003        Amex     106262.75 2024-02-22          1
# 5007     4451         4003        Amex     106262.75 2024-02-22          1

# %%
df = df.drop_duplicates(subset='card_id', keep='first')

# %%
df[df.duplicated('card_id', keep=False)]
# Out:
# Empty DataFrame
# Columns: [card_id, customer_id, card_type, limit_amount, issue_date, is_active]
# Index: []

# %%
df.shape
# Out:
# (5000, 6)

# %%
#credit_card.csv → fix negative limit_amount
df['limit_amount'] = df['limit_amount'].abs()
# Out:
# C:\Users\swath\AppData\Local\Temp\ipykernel_2724\1415523930.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['limit_amount'] = df['limit_amount'].abs()

# %%
df[df['limit_amount'] < 0]
# Out:
# Empty DataFrame
# Columns: [card_id, customer_id, card_type, limit_amount, issue_date, is_active]
# Index: []

# %%
df.dtypes
# Out:
# card_id                  int64
# customer_id              int64
# card_type               object
# limit_amount           float64
# issue_date      datetime64[ns]
# is_active                int64
# dtype: object

# %%
df.shape
# Out:
# (5000, 6)

# %%
df.to_csv(r"C:\Users\swath\Downloads\credit_card.csv" , index=False)
